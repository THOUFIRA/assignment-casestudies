# %%
# Import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the Dataset

# %%
# Load the dataset into a Pandas DataFrame
data=pd.read_csv('C:\\Users\\user\\Downloads\\Wine_clust .csv')

# %%
data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
# To check the first five rows of the dataset
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
# To check how many rows and columns are present in the given dataset
data.shape
# Out:
# (178, 13)

# %%
# To check some basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
# Preprocessing Steps

# %%
# Handling Missing Values

# %%
# To check the missing values in the given dataset
data.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
data.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
# Create box plots for each feature
fig, axs = plt.subplots(3, 5, figsize=(15, 10))  # Adjust the subplots based on the number of features
fig.subplots_adjust(hspace=0.5)  # Adjust the spacing between subplots

for i, column in enumerate(data.columns):
    row = i // 5
    col = i % 5
    axs[row, col].boxplot(data[column])
    axs[row, col].set_title(column)
plt.show()

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
outlier_indices = np.where((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))

# %%
outlier_indices
# Out:
# (array([ 25,  59,  59,  69,  73,  73,  78,  95,  95, 110, 115, 121, 121,
#         123, 127, 137, 151, 158, 159, 166, 173], dtype=int64),
#  array([ 2,  2,  3,  4,  3,  4,  4,  4,  8,  8, 10,  2,  3,  1,  3,  1,  9,
#          9,  9,  9,  1], dtype=int64))

# %%
# Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

scaled_data = pd.DataFrame(scaled_data,columns = data.columns)

# %%
from sklearn.decomposition import PCA
pca=PCA().fit(scaled_data)
plt.rcParams["figure.figsize"]=(12,6)
fig,ax=plt.subplots()
xi=np.arange(1,14,step=1)
y=np.cumsum(pca.explained_variance_ratio_)
plt.ylim(0.0,1.1)
plt.plot(xi,y,marker='o',linestyle='--',color='b')
plt.xlabel('Number of Components')
plt.xticks(np.arange(0,14,step=1))
plt.ylabel('Cumulative variance(%)')
plt.title('The number of components needed to explain variance')
plt.axhline(y=0.97,color='r',linestyle='-')
plt.text(0.5,0.85,'97% cut-off threshold',color='red',fontsize=16)
ax.grid(axis='x')
plt.show()

# %%
# Perform PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.97)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)

# %%
x_pca.shape
# Out:
# (178, 11)

# %%
# Cluster Models

# %%
# 1. K-Means Clustering

# %%
from sklearn.cluster import KMeans

# Finding the Optimum Number of Clusters
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init= 'k-means++', random_state=42)
    kmeans.fit(x_pca)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Plot the elbow curve
plt.plot(range(1,11), wcss)
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.title("Elbow Curve for K-means")
plt.show()

# %% [markdown]
# ### From the Elbow Curve , the optimum number of clusters = 3

# %%
# K-means clustering model
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
kmeans_pred=kmeans.fit_predict(x_pca)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Evaluation Metrics

# %%
from sklearn.metrics import silhouette_score

kmeans_silhouette = silhouette_score(x_pca,kmeans_pred)
print(kmeans_silhouette)
# Out:
# 0.2919562248268694

# %%
# 2. Heirarchical Clustering (Agglomerative)

# %%
import scipy.cluster.hierarchy as sch 

# Finding the Optimum Number of Clusters
dendrogram= sch.dendrogram(sch.linkage(x_pca,method='ward'))
plt.title('Dendrogram')
plt.xlabel('Number Of Clusters')
plt.ylabel('Euclidean Distances')
plt.show()

# %% [markdown]
# ### From the Dendrogram , the optimum number of clusters = 3

# %%
# Agglomerative Clustering Models
from sklearn.cluster import AgglomerativeClustering

agg=AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='ward')
agg_pred = agg.fit_predict(x_pca)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# Evaluation Metrics

# %%
from sklearn.metrics import silhouette_score

agg_silhouette = silhouette_score(x_pca,agg_pred)
print(agg_silhouette)
# Out:
# 0.28495044243291107

# %%
# 3. DBSCAN Clustering

# %%
# Finding Optimal Value of Epsilon
from sklearn.neighbors import NearestNeighbors

nearest_neighbors = NearestNeighbors(n_neighbors=23)
neighbors = nearest_neighbors.fit(scaled_data)

distances, indices = neighbors.kneighbors(scaled_data)
k_distances = np.sort(distances[:,22], axis=0)

# %%
# PLot the nearest neighbor
fig = plt.figure(figsize=(15, 8))
plt.plot(k_distances)
plt.xlabel("Points")
plt.ylabel("Distance")
plt.show()

# %%
# Finding the knee location
from kneed import KneeLocator

knee = KneeLocator(range(1,len(k_distances)+1), k_distances, S = 1.0, curve='convex', direction='increasing')

# %%
# Plot the knee locator
fig = plt.figure(figsize=(15, 8))
knee.plot_knee()
plt.xlabel("Points")
plt.ylabel("Distance")
plt.show()

# %%
# print the knee locator
print(k_distances[knee.knee])
# Out:
# 3.887521367628469

# %%
# DBSCAN Clustering Models
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps = 3.887, min_samples = 22)
dbscan_labels = dbscan.fit_predict(scaled_data)

# %%
# Get the number of clusters (excluding noise)
n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
print("Number of clusters:", n_clusters)

# Identify and count the number of noise points
n_noise_points = list(dbscan_labels).count(-1)
print("Number of noise points:", n_noise_points)
# Out:
# Number of clusters: 1
# Number of noise points: 7

# %%
# Evaluation Metrics

# %%
from sklearn.metrics import silhouette_score

dbscan_silhouette = silhouette_score(scaled_data, dbscan_labels)
print(dbscan_silhouette)
# Out:
# 0.24274394351928288

# %%
print('K-Means Silhouette Score : ' ,kmeans_silhouette)
print('Agglomerative Heirarchical Silhouette Score : ' ,agg_silhouette)
print('DBSCAN Silhouette Score : ' ,dbscan_silhouette)
# Out:
# K-Means Silhouette Score :  0.2919562248268694
# Agglomerative Heirarchical Silhouette Score :  0.28495044243291107
# DBSCAN Silhouette Score :  0.24274394351928288

# %% [markdown]
# #### Silhouette Score for KMeans Clustering is higher . So it is the best model .
