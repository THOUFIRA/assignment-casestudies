# %%
# importing necessary library needed for our data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the data
df=pd.read_csv('C:\\Users\\user\\Downloads\\StudentsPerformance.csv')

# %%
# print the data
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#printing first five rows
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     85
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# # 1.

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
value=df['gender'].value_counts().rename_axis('type').reset_index(name='counts')
value
# Out:
#      type  counts
# 0  female     518
# 1    male     482

# %%
plt.pie(value["counts"],labels=value["type"],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # 2.

# %%
parents=df['parental level of education'].value_counts()
parents
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='parental level of education',data=df)
plt.show()

# %%
df.groupby(by='parental level of education').mean(numeric_only=True)
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.977477      71.018018      70.031532
# bachelor's degree             69.288136      73.000000      73.381356
# high school                   61.821429      64.602041      62.403061
# master's degree               70.254237      75.949153      75.677966
# some college                  67.128319      69.566372      69.035398
# some high school              63.134078      66.759777      64.888268

# %%
df.groupby(by=['parental level of education']).mean(numeric_only=True).plot.bar()
plt.show()

# %%
#Students score tend to increase directly as per their parent's education. Parents having master's degree have a significant impact on students to score more than those parents who only have a high school degree.

# %% [markdown]
# # 3.

# %%
df.groupby('gender')['math score','reading score','writing score'].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\2742975150.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('gender')['math score','reading score','writing score'].mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
df.groupby('gender')['math score','reading score','writing score'].mean().plot.bar()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\4067523490.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('gender')['math score','reading score','writing score'].mean().plot.bar()

# %%
df.groupby(['gender','parental level of education'])[['math score','reading score','writing score']].mean().plot.bar()
plt.show()

# %%
#students with the same parental level of education,female students have higher average reading and writing scores than male.where male students have higher average math score

# %%
df.groupby('test preparation course')['math score','reading score','writing score'].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\2005058511.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('test preparation course')['math score','reading score','writing score'].mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
df.groupby('test preparation course')['math score','reading score','writing score'].mean().plot.bar()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\750469554.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('test preparation course')['math score','reading score','writing score'].mean().plot.bar()

# %%
df.groupby(['test preparation course','parental level of education'])[['math score','reading score','writing score']].mean().plot.bar()
plt.show()

# %%
# students who have completed the test preparation course and with a bachelor's degree as the parental level of education have higher average math scores
# students who have completed the test preparation course and with a master's degree as the parental level of education have higher average reading scores and writing scores

# %% [markdown]
# # 4.

# %%
df.groupby('gender')['math score','reading score','writing score'].var()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\2070823677.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('gender')['math score','reading score','writing score'].var()
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
df.groupby('gender')['math score','reading score','writing score'].var().plot.bar()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\1626088543.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('gender')['math score','reading score','writing score'].var().plot.bar()

# %%
df.groupby('test preparation course')['math score','reading score','writing score'].var()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\3669111096.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('test preparation course')['math score','reading score','writing score'].var()
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %%
df.groupby('test preparation course')['math score','reading score','writing score'].var().plot.bar()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1208\89688004.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('test preparation course')['math score','reading score','writing score'].var().plot.bar()

# %% [markdown]
# # 5.

# %%
df['math score'].quantile(0.25)
# Out:
# 57.0

# %%
top25=df[df['math score']<=57].sort_values(['math score'],ascending=False)
top25
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 619    male        group E                 high school  free/reduced
# 162  female        group E                 high school  free/reduced
# 153  female        group B          associate's degree      standard
# 154  female        group B            some high school      standard
# 155  female        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
plt.boxplot(df['math score'])
plt.show()
